# %% [markdown]
# # Linked Lists
# <blockquote>A linked list is a data structure that consists of sequence of <em>nodes</em>. Each node is composed of two fields: <b>data field</b> and <b>reference field</b> which is a pointer that points to the next node in the sequence.</blockquote>In Linked List, we use the features of C language like Pointers, Structs, and dynamic memory allocation to create robust data structures.
# [Read More](http://docs.cs50.net/2016/fall/notes/5/week5.html#linked-lists).

# %% [markdown]
# I'll be working in C language today, as it makes more sense. The output of the program will be displayed in this Notebook along with a link to the source code.<br>This demonstration will cover:
# <ul>
# <li>Creating Linked List</li>
# <li>Adding and removing nodes</li>
# <li>Deleting Linked List</li>
# <li>Searching</li>
# </ul>
#
# This implementation will cover Doubly Linked Lists as the nodes can be added and removed from both ends.

# %% [markdown]
# ## Complexity
# Both have time complexities: <br>
# Access: $\theta(n)$<br>
# Search: $\theta(n)$<br>
# Insertion: $\theta(1)$<br>
# Deletion: $\theta(1)$

# %%
from IPython.display import Latex, FileLink

# %%
print("Source Code:")
FileLink('Day_16_-_LinkedLists.c')
# Out:
# Source Code:
# C:\Users\RajaHasnain\Documents\GitHub\100_days_of_algorithms\Day_16_-_LinkedLists.c

# %%
print("Main:")
FileLink('Day_16_main.c')
# Out:
# Main:
# C:\Users\RajaHasnain\Documents\GitHub\100_days_of_algorithms\Day_16_main.c

# %% [markdown]
# The output of the code is given below but it is not very clearly readable.

# %%
from subprocess import check_output
check_output(["./output"])
# Out:
# b'Linked List: [ ]\r\n\r\nAdding 7\r\nLinked List: [ 7 ]\r\n\r\nAdding 1 in front\r\nLinked List: [ 1 7 ]\r\n\r\nAdding 5 to the end\r\nLinked List: [ 1 7 5 ]\r\n\r\nAdding 6\r\nLinked List: [ 6 1 7 5 ]\r\n\r\nRemoving the front node\r\nLinked List: [ 1 7 5 ]\r\n\r\nRemoving the end node\r\nLinked List: [ 1 7 ]\r\n\r\nSearching 6...\r\nNOT FOUND\r\n\r\nSearching 1....\r\nFOUND!\r\n\r\nDestroying...\r\nLinked List: [ 1 ]\r\n'

# %%
from IPython.display import Image
Image('Day_16_-_LinkedLists_Output.JPG')
